# %% [markdown]
# <a href="https://colab.research.google.com/github/Untick/InspectrumClinic_RS_gr1/blob/Lyakhov-Igor-folder/%D0%98%D0%B3%D0%BE%D1%80%D1%8C_%D0%9B%D1%8F%D1%85%D0%BE%D0%B2_setup_of_git.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Рекомендательная система для профпатолога (INSPECTRUM CLINIC)

# %% [markdown]
# ## Анализ датасета

# %%
# Загружаем датасет
import pandas as pd
# Библиотека для работы с массивами данных
import numpy as np
# Библиотека для построения графиков
import matplotlib.pyplot as plt
# Библиотека для построения графиков
import seaborn as sns
import gdown
gdown.download('https://storage.yandexcloud.net/terratraineeship/23_InspectrumClinic_RS/datasets/%D0%B4%D0%B0%D1%82%D0%B0%D1%81%D0%B5%D1%82%20%D0%BF%D1%80%D0%BE%D1%84%D0%BF%D0%B0%D1%82%D0%BE%D0%BB%D0%BE%D0%B3%20%D1%87%D0%B0%D1%81%D1%82%D1%8C.xlsx', None, quiet=True)
# Out:
# '%D0%B4%D0%B0%D1%82%D0%B0%D1%81%D0%B5%D1%82%20%D0%BF%D1%80%D0%BE%D1%84%D0%BF%D0%B0%D1%82%D0%BE%D0%BB%D0%BE%D0%B3%20%D1%87%D0%B0%D1%81%D1%82%D1%8C.xlsx'

# %%
# Считывание и запись данных
data = pd.read_excel('%D0%B4%D0%B0%D1%82%D0%B0%D1%81%D0%B5%D1%82%20%D0%BF%D1%80%D0%BE%D1%84%D0%BF%D0%B0%D1%82%D0%BE%D0%BB%D0%BE%D0%B3%20%D1%87%D0%B0%D1%81%D1%82%D1%8C.xlsx')

# %%
data
# Out:
#              ДокументПрохождениеМедосмотра  \
# 0     7f41ca7e-7dac-11ec-80fc-0cc47aab8067
# 1     2ee1f9ac-83dd-11ec-80fc-0cc47aab8067
# 2     9cbb191e-8e24-11ec-80fe-0cc47aab8067
# 3     b8a33910-8eec-11ec-80fe-0cc47aab8067
# 4     0bb0d181-938c-11ec-80fe-0cc47aab8067
# ...                                    ...
# 1977  137af572-70a5-11ed-8109-0cc47aab8067
# 1978  26310d7e-70a5-11ed-8109-0cc47aab8067
# 1979  b2602553-705c-11ed-8109-0cc47aab8067
# 1980  d0358b83-7065-11ed-8109-0cc47aab8067
# 1981  a15e278b-71f5-11ed-810a-0cc47aab8067
#
#                                     Клиент КлиентДатаРождения КлиентПол  \
# 0     c91e3407-b81f-11e9-80cf-0cc47aab8067         1976-10-24   Женский
# 1     1a1a5fea-8b7f-11eb-80e8-0cc47aab8067         1987-11-18   Мужской
# 2     7fe324e0-fa51-11eb-80f6-0cc47aab8067         1985-09-08   Мужской
# 3     98f9d761-8d65-11ec-80fe-0cc47aab8067         1988-04-25   Мужской
# 4     009aac7d-7bcf-11eb-80e8-0cc47aab8067         1984-04-17   Мужской
# ...                                    ...                ...       ...
# 1977  41a7c665-7098-11ed-8109-0cc47aab8067         1972-11-12   Мужской
# 1978  41a7c663-7098-11ed-8109-0cc47aab8067         1986-07-09   Мужской
# 1979  0dc52156-f1a9-11e9-80d1-0cc47aab8067         1994-05-12   Мужской
# 1980  6261a674-07c8-11e8-80c6-0cc47aab8067         1972-04-17   Женский
# 1981  920293ea-32c2-11eb-80e3-0cc47aab8067         1971-09-14   Мужской
#
#      КлиентПолПредставление ДатаЗавершенияМедосмотра  ТипМедосмотра  \
# 0                   Женский               2022-01-25  Периодический
# 1                   Мужской               2022-02-02  Периодический
# 2                   Мужской               2022-02-15  Периодический
# 3                   Мужской               2022-02-16  Периодический
# 4                   Мужской               2022-02-22  Периодический
# ...                     ...                      ...            ...
# 1977                Мужской               2022-11-30  Периодический
# 1978                Мужской               2022-11-30  Периодический
# 1979                Мужской               2022-11-30  Периодический
# 1980                Женский               2022-11-30  Периодический
# 1981                Мужской               2022-12-02  Периодический
#
#      ТипМедосмотраПредставление  ПсихОсвидетельствование  \
# 0                 Периодический                    False
# 1                 Периодический                    False
# 2                 Периодический                    False
# 3                 Периодический                    False
# 4                 Периодический                    False
# ...                         ...                      ...
# 1977              Периодический                    False
# 1978              Периодический                    False
# 1979              Периодический                    False
# 1980              Периодический                    False
# 1981              Периодический                    False
#
#                                 Контрагент  ...  \
# 0     23c173a7-30d9-11e7-80d8-708bcd7f83cd  ...
# 1     a6d559b0-7835-11eb-80e8-0cc47aab8067  ...
# 2     a6d559b0-7835-11eb-80e8-0cc47aab8067  ...
# 3     a6d559b0-7835-11eb-80e8-0cc47aab8067  ...
# 4     a6d559b0-7835-11eb-80e8-0cc47aab8067  ...
# ...                                    ...  ...
# 1977  a9f70e4c-707f-11ed-8109-0cc47aab8067  ...
# 1978  a9f70e4c-707f-11ed-8109-0cc47aab8067  ...
# 1979  e689a382-17b2-11e9-80ce-0cc47aab8067  ...
# 1980  21f2a93d-68f9-11e6-82dc-d897ba0a5c60  ...
# 1981  4826f33a-06b9-11ea-80d3-0cc47aab8067  ...
#
#      Оториноларингология3_Аудиометрия1_Значение  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 1977                                        NaN
# 1978                                        NaN
# 1979                                        NaN
# 1980                                        NaN
# 1981                                        NaN
#
#      Оториноларингология3_Аудиометрия1_ЗначениеПредставление  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1977                                                NaN
# 1978                                                NaN
# 1979                                                NaN
# 1980                                                NaN
# 1981                                                NaN
#
#      Оториноларингология1_ЖалобыДополнение_Значение  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ...                                             ...
# 1977                                            NaN
# 1978                                            NaN
# 1979                                            NaN
# 1980                                            NaN
# 1981                                            NaN
#
#      Оториноларингология1_ЖалобыДополнение_ЗначениеПредставление  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1977                                                NaN
# 1978                                                NaN
# 1979                                                NaN
# 1980                                                NaN
# 1981                                                NaN
#
#      Стоматология2_ВП2_Значение Стоматология2_ВП2_ЗначениеПредставление  \
# 0                           NaN                                     NaN
# 1                           NaN                                     NaN
# 2                           NaN                                     NaN
# 3                           NaN                                     NaN
# 4                           NaN                                     NaN
# ...                         ...                                     ...
# 1977                        NaN                                     NaN
# 1978                        NaN                                     NaN
# 1979                        NaN                                     NaN
# 1980                        NaN                                     NaN
# 1981                        NaN                                     NaN
#
#      Терапия2_ЗаключениеФОГК_Значение  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# ...                               ...
# 1977                              NaN
# 1978                              NaN
# 1979                              NaN
# 1980                              NaN
# 1981                              NaN
#
#      Терапия2_ЗаключениеФОГК_ЗначениеПредставление  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ...                                            ...
# 1977                                           NaN
# 1978                                           NaN
# 1979                                           NaN
# 1980                                           NaN
# 1981                                           NaN
#
#      Офтальмология1_ДвигательныйАппаратГлазДополнение_Значение  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1977                                                NaN
# 1978                                                NaN
# 1979                                                NaN
# 1980                                                NaN
# 1981                                                NaN
#
#      Офтальмология1_ДвигательныйАппаратГлазДополнение_ЗначениеПредставление
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1977                                                NaN
# 1978                                                NaN
# 1979                                                NaN
# 1980                                                NaN
# 1981                                                NaN
#
# [1982 rows x 4587 columns]

# %%
# Количество строк и столбцов
data.shape
# Out:
# (1982, 4587)

# %%
# Количество элементов в таблице
data.size
# Out:
# 9091434

# %%
# количество непустых записей в каждом столбце
data.count()
# Out:
# ДокументПрохождениеМедосмотра                                             1982
# Клиент                                                                    1982
# КлиентДатаРождения                                                        1982
# КлиентПол                                                                 1982
# КлиентПолПредставление                                                    1982
#                                                                           ...
# Стоматология2_ВП2_ЗначениеПредставление                                      1
# Терапия2_ЗаключениеФОГК_Значение                                             1
# Терапия2_ЗаключениеФОГК_ЗначениеПредставление                                1
# Офтальмология1_ДвигательныйАппаратГлазДополнение_Значение                    1
# Офтальмология1_ДвигательныйАппаратГлазДополнение_ЗначениеПредставление       1
# Length: 4587, dtype: int64

# %%
# тип данных каждого столбца
data.dtypes
# Out:
# ДокументПрохождениеМедосмотра                                                     object
# Клиент                                                                            object
# КлиентДатаРождения                                                        datetime64[ns]
# КлиентПол                                                                         object
# КлиентПолПредставление                                                            object
#                                                                                ...
# Стоматология2_ВП2_ЗначениеПредставление                                           object
# Терапия2_ЗаключениеФОГК_Значение                                                  object
# Терапия2_ЗаключениеФОГК_ЗначениеПредставление                                     object
# Офтальмология1_ДвигательныйАппаратГлазДополнение_Значение                         object
# Офтальмология1_ДвигательныйАппаратГлазДополнение_ЗначениеПредставление            object
# Length: 4587, dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1982 entries, 0 to 1981
# Columns: 4587 entries, ДокументПрохождениеМедосмотра to Офтальмология1_ДвигательныйАппаратГлазДополнение_ЗначениеПредставление
# dtypes: bool(1), datetime64[ns](43), float64(1253), object(3290)
# memory usage: 69.3+ MB

# %%
# bool type columns
bool_cols = data.dtypes[data.dtypes == 'bool']
bool_cols_count = len(bool_cols)
print(f'Колоноки типа bool: {bool_cols_count}')
print('-'*50)
print(bool_cols)
# Out:
# Колоноки типа bool: 1
# --------------------------------------------------
# ПсихОсвидетельствование    bool
# dtype: object

# %%
# datetime64[ns] type columns
datetime_cols = data.dtypes[data.dtypes == 'datetime64[ns]']
datetime_cols_count = len(datetime_cols)
print(f'Колоноки типа datetime: {datetime_cols_count}')
print('-'*50)
print(datetime_cols)
# Out:
# Колоноки типа datetime: 43
# --------------------------------------------------
# КлиентДатаРождения                                        datetime64[ns]
# ДатаЗавершенияМедосмотра                                  datetime64[ns]
# ЛабораторныеИсследования1_ДатаПриема                      datetime64[ns]
# Рентгенология1_ДатаПриема                                 datetime64[ns]
# Рентгенология2_ДатаПриема                                 datetime64[ns]
# ПсихиатрияНаркология1_ДатаПриема                          datetime64[ns]
# Офтальмология1_ДатаПриема                                 datetime64[ns]
# Оториноларингология1_ДатаПриема                           datetime64[ns]
# ХирургНеИсп1_ДатаПриема                                   datetime64[ns]
# Гинекология1_ДатаПриема                                   datetime64[ns]
# ФункциональнаяДиагностика1_ДатаПриема                     datetime64[ns]
# Стоматология1_ДатаПриема                                  datetime64[ns]
# Эндоскопия1_ДатаПриема                                    datetime64[ns]
# Терапия1_ДатаПриема                                       datetime64[ns]
# Дерматовенерология1_ДатаПриема                            datetime64[ns]
# Неврология1_ДатаПриема                                    datetime64[ns]
# УЗИДиагностика1_ДатаПриема                                datetime64[ns]
# Хирургия1_ДатаПриема                                      datetime64[ns]
# Хирургия2_ДатаПриема                                      datetime64[ns]
# Терапия2_ДатаПриема                                       datetime64[ns]
# Неврология2_ДатаПриема                                    datetime64[ns]
# Неврология2_ДатаПриема_Значение                           datetime64[ns]
# Неврология2_ДатаПриема_ЗначениеПредставление              datetime64[ns]
# УЗИДиагностика2_ДатаПриема                                datetime64[ns]
# ЭКГНеИсп1_ДатаПриема                                      datetime64[ns]
# ПроцедурнаяМедсестра1_ДатаПриема                          datetime64[ns]
# ПсихиатрияНаркология2_ДатаПриема                          datetime64[ns]
# ПсихиатрияНаркология2_ДатаПриема_Значение                 datetime64[ns]
# ПсихиатрияНаркология2_ДатаПриема_ЗначениеПредставление    datetime64[ns]
# ЛабораторныеИсследования2_ДатаПриема                      datetime64[ns]
# Психиатрия1_ДатаПриема                                    datetime64[ns]
# Психиатрия1_ДатаПриема_Значение                           datetime64[ns]
# Психиатрия1_ДатаПриема_ЗначениеПредставление              datetime64[ns]
# Гинекология2_ДатаПриема                                   datetime64[ns]
# Гинекология2_ДатаПриема_Значение                          datetime64[ns]
# Гинекология2_ДатаПриема_ЗначениеПредставление             datetime64[ns]
# Гинекология2_ДатаПоследнейMensis_Значение                 datetime64[ns]
# Гинекология2_ДатаПоследнейMensis_ЗначениеПредставление    datetime64[ns]
# Эндоскопия2_ДатаПриема                                    datetime64[ns]
# Стоматология2_ДатаПриема                                  datetime64[ns]
# Стоматология2_ДатаПриема_Значение                         datetime64[ns]
# Стоматология2_ДатаПриема_ЗначениеПредставление            datetime64[ns]
# ФункциональнаяДиагностика2_ДатаПриема                     datetime64[ns]
# dtype: object

# %%
# float64 type columns
float_cols = data.dtypes[data.dtypes == 'float64']
float_cols_count = len(float_cols)
print(f'Колоноки типа float: {float_cols_count}')
print('-'*50)
print(float_cols)
# Out:
# Колоноки типа float: 1253
# --------------------------------------------------
# ЛабораторныеИсследования1_ХР_Рекомендация2Представление    float64
# ЛабораторныеИсследования1_ХР_РекомендацияСтр               float64
# Рентгенология1_ХР_Рекомендация1                            float64
# Рентгенология1_ХР_Рекомендация1Представление               float64
# Рентгенология1_ХР_Рекомендация2                            float64
#                                                             ...
# Оториноларингология3_Классификация2Представление1          float64
# Оториноларингология3_Классификация31                       float64
# Оториноларингология3_Классификация3Представление1          float64
# Оториноларингология3_Противопоказание1                     float64
# Оториноларингология3_ПротивопоказаниеПредставление1        float64
# Length: 1253, dtype: object

# %%
# object-string type columns
obj_cols = data.dtypes[data.dtypes == 'O']
obj_cols_count = len(obj_cols)
print(f'Колоноки типа object: {obj_cols_count}')
print('-'*50)
print(obj_cols)
# Out:
# Колоноки типа object: 3290
# --------------------------------------------------
# ДокументПрохождениеМедосмотра                                             object
# Клиент                                                                    object
# КлиентПол                                                                 object
# КлиентПолПредставление                                                    object
# ТипМедосмотра                                                             object
#                                                                            ...
# Стоматология2_ВП2_ЗначениеПредставление                                   object
# Терапия2_ЗаключениеФОГК_Значение                                          object
# Терапия2_ЗаключениеФОГК_ЗначениеПредставление                             object
# Офтальмология1_ДвигательныйАппаратГлазДополнение_Значение                 object
# Офтальмология1_ДвигательныйАппаратГлазДополнение_ЗначениеПредставление    object
# Length: 3290, dtype: object

# %%
# число колонок
total_cols_count = bool_cols_count + datetime_cols_count + float_cols_count + obj_cols_count
print('Число колонок:')
print(f'  bool: {bool_cols_count}')
print(f'  datetime64[ns]: {datetime_cols_count}')
print(f'  float64: {float_cols_count}')
print(f'  object-string: {obj_cols_count}')
print('-'*50)
print(f'Общее число колонок: {total_cols_count}')
# Out:
# Число колонок:
#   bool: 1
#   datetime64[ns]: 43
#   float64: 1253
#   object-string: 3290
# --------------------------------------------------
# Общее число колонок: 4587

# %%
# названия колонок
col_names = list(data.columns)
col_names_count = len(col_names)
print(f'Число названий колонок: {col_names_count}')
print('-'*50)
print(col_names)
# Out:
# Число названий колонок: 4587
# --------------------------------------------------
# ['ДокументПрохождениеМедосмотра', 'Клиент', 'КлиентДатаРождения', 'КлиентПол', 'КлиентПолПредставление', 'ДатаЗавершенияМедосмотра', 'ТипМедосмотра', 'ТипМедосмотраПредставление', 'ПсихОсвидетельствование', 'Контрагент', 'Цех', 'Профессия', 'ЗаключениеМК', 'ЗаключениеМКПредставление', 'Заключение', 'ДиспансернаяГруппа', 'ДиспансернаяГруппаПредставление', 'ВредныеФакторы', 'ЛабораторныеИсследования1_ДокументПрием', 'ЛабораторныеИсследования1_ДатаПриема', 'ЛабораторныеИсследования1_Салон', 'ЛабораторныеИсследования1_СалонПредставление', 'ЛабораторныеИсследования1_Специализация', 'ЛабораторныеИсследования1_СпециализацияПредставление', 'ЛабораторныеИсследования1_ХР_Рекомендация1', 'ЛабораторныеИсследования1_ХР_Рекомендация1Представление', 'ЛабораторныеИсследования1_ХР_Рекомендация2', 'ЛабораторныеИсследования1_ХР_Рекомендация2Представление', 'ЛабораторныеИсследования1_ХР_РекомендацияСтр', 'ЛабораторныеИсследования1_ОАК_Значение', 'ЛабораторныеИсследования1_ОАК_ЗначениеПредставление', 'ЛабораторныеИсследования1_Биохимия_Значение', 'ЛабораторныеИсследования1_Биохимия_ЗначениеПредставление', 'ЛабораторныеИсследования1_ОАМ_Значение', 'ЛабораторныеИсследования1_ОАМ_ЗначениеПредставление', 'ЛабораторныеИсследования1_МазокИзЗеваИНоса_Значение', 'ЛабораторныеИсследования1_МазокИзЗеваИНоса_ЗначениеПредставление', 'ЛабораторныеИсследования1_Кал_Значение', 'ЛабораторныеИсследования1_Кал_ЗначениеПредставление', 'ЛабораторныеИсследования1_RW_Значение', 'ЛабораторныеИсследования1_RW_ЗначениеПредставление', 'ЛабораторныеИсследования1_КровьНаЭнтеробиоз_Значение', 'ЛабораторныеИсследования1_КровьНаЭнтеробиоз_ЗначениеПредставление', 'Рентгенология1_ДокументПрием', 'Рентгенология1_ДатаПриема', 'Рентгенология1_Салон', 'Рентгенология1_СалонПредставление', 'Рентгенология1_Специализация', 'Рентгенология1_СпециализацияПредставление', 'Рентгенология1_ХР_Рекомендация1', 'Рентгенология1_ХР_Рекомендация1Представление', 'Рентгенология1_ХР_Рекомендация2', 'Рентгенология1_ХР_Рекомендация2Представление', 'Рентгенология1_ХР_РекомендацияСтр', 'Рентгенология1_Легкие_Значение', 'Рентгенология1_Легкие_ЗначениеПредставление', 'Рентгенология1_Сердце_Значение', 'Рентгенология1_Сердце_ЗначениеПредставление', 'Рентгенология1_Заключение_Значение', 'Рентгенология1_Заключение_ЗначениеПредставление', 'Рентгенология2_ДокументПрием', 'Рентгенология2_ДатаПриема', 'Рентгенология2_Салон', 'Рентгенология2_СалонПредставление', 'Рентгенология2_Специализация', 'Рентгенология2_СпециализацияПредставление', 'Рентгенология2_ХР_Рекомендация1', 'Рентгенология2_ХР_Рекомендация1Представление', 'Рентгенология2_ХР_Рекомендация2', 'Рентгенология2_ХР_Рекомендация2Представление', 'Рентгенология2_ХР_РекомендацияСтр', 'ПсихиатрияНаркология1_ДокументПрием', 'ПсихиатрияНаркология1_ДатаПриема', 'ПсихиатрияНаркология1_Салон', 'ПсихиатрияНаркология1_СалонПредставление', 'ПсихиатрияНаркология1_Специализация', 'ПсихиатрияНаркология1_СпециализацияПредставление', 'ПсихиатрияНаркология1_ХР_Рекомендация1', 'ПсихиатрияНаркология1_ХР_Рекомендация1Представление', 'ПсихиатрияНаркология1_ХР_Рекомендация2', 'ПсихиатрияНаркология1_ХР_Рекомендация2Представление', 'ПсихиатрияНаркология1_ХР_РекомендацияСтр', 'ПсихиатрияНаркология1_МКБ101', 'ПсихиатрияНаркология1_ДиагнозПредставление1', 'ПсихиатрияНаркология1_Детализация1', 'ПсихиатрияНаркология1_Классификация11', 'ПсихиатрияНаркология1_Классификация1Представление1', 'ПсихиатрияНаркология1_Классификация21', 'ПсихиатрияНаркология1_Классификация2Представление1', 'ПсихиатрияНаркология1_Классификация31', 'ПсихиатрияНаркология1_Классификация3Представление1', 'ПсихиатрияНаркология1_Противопоказание1', 'ПсихиатрияНаркология1_ПротивопоказаниеПредставление1', 'ПсихиатрияНаркология1_Профессиональное1', 'ПсихиатрияНаркология1_ПрофнепригодностьВременная1', 'ПсихиатрияНаркология1_ПрофнепригодностьВременнаяПредставление1', 'ПсихиатрияНаркология1_ДатаПриема_Значение', 'ПсихиатрияНаркология1_ДатаПриема_ЗначениеПредставление', 'ПсихиатрияНаркология1_Врач_Значение', 'ПсихиатрияНаркология1 ...

# %%
# количество пропусков в каждом столбце
data.isna().sum()
# Out:
# ДокументПрохождениеМедосмотра                                                0
# Клиент                                                                       0
# КлиентДатаРождения                                                           0
# КлиентПол                                                                    0
# КлиентПолПредставление                                                       0
#                                                                           ...
# Стоматология2_ВП2_ЗначениеПредставление                                   1981
# Терапия2_ЗаключениеФОГК_Значение                                          1981
# Терапия2_ЗаключениеФОГК_ЗначениеПредставление                             1981
# Офтальмология1_ДвигательныйАппаратГлазДополнение_Значение                 1981
# Офтальмология1_ДвигательныйАппаратГлазДополнение_ЗначениеПредставление    1981
# Length: 4587, dtype: int64

# %%
data.head()
# Out:
#           ДокументПрохождениеМедосмотра                                Клиент  \
# 0  7f41ca7e-7dac-11ec-80fc-0cc47aab8067  c91e3407-b81f-11e9-80cf-0cc47aab8067
# 1  2ee1f9ac-83dd-11ec-80fc-0cc47aab8067  1a1a5fea-8b7f-11eb-80e8-0cc47aab8067
# 2  9cbb191e-8e24-11ec-80fe-0cc47aab8067  7fe324e0-fa51-11eb-80f6-0cc47aab8067
# 3  b8a33910-8eec-11ec-80fe-0cc47aab8067  98f9d761-8d65-11ec-80fe-0cc47aab8067
# 4  0bb0d181-938c-11ec-80fe-0cc47aab8067  009aac7d-7bcf-11eb-80e8-0cc47aab8067
#
#   КлиентДатаРождения КлиентПол КлиентПолПредставление  \
# 0         1976-10-24   Женский                Женский
# 1         1987-11-18   Мужской                Мужской
# 2         1985-09-08   Мужской                Мужской
# 3         1988-04-25   Мужской                Мужской
# 4         1984-04-17   Мужской                Мужской
#
#   ДатаЗавершенияМедосмотра  ТипМедосмотра ТипМедосмотраПредставление  \
# 0               2022-01-25  Периодический              Периодический
# 1               2022-02-02  Периодический              Периодический
# 2               2022-02-15  Периодический              Периодический
# 3               2022-02-16  Периодический              Периодический
# 4               2022-02-22  Периодический              Периодический
#
#    ПсихОсвидетельствование                            Контрагент  ...  \
# 0                    False  23c173a7-30d9-11e7-80d8-708bcd7f83cd  ...
# 1                    False  a6d559b0-7835-11eb-80e8-0cc47aab8067  ...
# 2                    False  a6d559b0-7835-11eb-80e8-0cc47aab8067  ...
# 3                    False  a6d559b0-7835-11eb-80e8-0cc47aab8067  ...
# 4                    False  a6d559b0-7835-11eb-80e8-0cc47aab8067  ...
#
#   Оториноларингология3_Аудиометрия1_Значение  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#   Оториноларингология3_Аудиометрия1_ЗначениеПредставление  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Оториноларингология1_ЖалобыДополнение_Значение  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   Оториноларингология1_ЖалобыДополнение_ЗначениеПредставление  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Стоматология2_ВП2_Значение Стоматология2_ВП2_ЗначениеПредставление  \
# 0                        NaN                                     NaN
# 1                        NaN                                     NaN
# 2                        NaN                                     NaN
# 3                        NaN                                     NaN
# 4                        NaN                                     NaN
#
#   Терапия2_ЗаключениеФОГК_Значение  \
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
#
#   Терапия2_ЗаключениеФОГК_ЗначениеПредставление  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   Офтальмология1_ДвигательныйАппаратГлазДополнение_Значение  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Офтальмология1_ДвигательныйАппаратГлазДополнение_ЗначениеПредставление
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 4587 columns]

# %%
data.isna().head()
# Out:
#    ДокументПрохождениеМедосмотра  Клиент  КлиентДатаРождения  КлиентПол  \
# 0                          False   False               False      False
# 1                          False   False               False      False
# 2                          False   False               False      False
# 3                          False   False               False      False
# 4                          False   False               False      False
#
#    КлиентПолПредставление  ДатаЗавершенияМедосмотра  ТипМедосмотра  \
# 0                   False                     False          False
# 1                   False                     False          False
# 2                   False                     False          False
# 3                   False                     False          False
# 4                   False                     False          False
#
#    ТипМедосмотраПредставление  ПсихОсвидетельствование  Контрагент  ...  \
# 0                       False                    False       False  ...
# 1                       False                    False       False  ...
# 2                       False                    False       False  ...
# 3                       False                    False       False  ...
# 4                       False                    False       False  ...
#
#    Оториноларингология3_Аудиометрия1_Значение  \
# 0                                        True
# 1                                        True
# 2                                        True
# 3                                        True
# 4                                        True
#
#    Оториноларингология3_Аудиометрия1_ЗначениеПредставление  \
# 0                                               True
# 1                                               True
# 2                                               True
# 3                                               True
# 4                                               True
#
#    Оториноларингология1_ЖалобыДополнение_Значение  \
# 0                                            True
# 1                                            True
# 2                                            True
# 3                                            True
# 4                                            True
#
#    Оториноларингология1_ЖалобыДополнение_ЗначениеПредставление  \
# 0                                               True
# 1                                               True
# 2                                               True
# 3                                               True
# 4                                               True
#
#    Стоматология2_ВП2_Значение  Стоматология2_ВП2_ЗначениеПредставление  \
# 0                        True                                     True
# 1                        True                                     True
# 2                        True                                     True
# 3                        True                                     True
# 4                        True                                     True
#
#    Терапия2_ЗаключениеФОГК_Значение  \
# 0                              True
# 1                              True
# 2                              True
# 3                              True
# 4                              True
#
#    Терапия2_ЗаключениеФОГК_ЗначениеПредставление  \
# 0                                           True
# 1                                           True
# 2                                           True
# 3                                           True
# 4                                           True
#
#    Офтальмология1_ДвигательныйАппаратГлазДополнение_Значение  \
# 0                                               True
# 1                                               True
# 2                                               True
# 3                                               True
# 4                                               True
#
#    Офтальмология1_ДвигательныйАппаратГлазДополнение_ЗначениеПредставление
# 0                                               True
# 1                                               True
# 2                                               True
# 3                                               True
# 4                                               True
#
# [5 rows x 4587 columns]

# %%
# долю пропусков от общего количества элементов
data.isna().sum() / data.shape[0]
# Out:
# ДокументПрохождениеМедосмотра                                             0.000000
# Клиент                                                                    0.000000
# КлиентДатаРождения                                                        0.000000
# КлиентПол                                                                 0.000000
# КлиентПолПредставление                                                    0.000000
#                                                                             ...
# Стоматология2_ВП2_ЗначениеПредставление                                   0.999495
# Терапия2_ЗаключениеФОГК_Значение                                          0.999495
# Терапия2_ЗаключениеФОГК_ЗначениеПредставление                             0.999495
# Офтальмология1_ДвигательныйАппаратГлазДополнение_Значение                 0.999495
# Офтальмология1_ДвигательныйАппаратГлазДополнение_ЗначениеПредставление    0.999495
# Length: 4587, dtype: float64

# %%
# общее количество пропусков во всей таблице
data.isna().sum().sum()
# Out:
# 8106978

# %%
# общее количество пропусков во всей таблице в %
proc = data.isna().sum().sum() / data.size
print('{:.1%}'.format(proc))
# Out:
# 89.2%

# %%
# Поиск признаков с пропусками
null_cols = data.columns[data.isna().any()].tolist()
null_cols_len = len(null_cols)
print(f'Колоноки с пропусками: {null_cols_len}')

for i in range(null_cols_len):
  if 'ЗаключениеМК' == null_cols[i]:
    print(f'null_cols[{i}]: {null_cols[i]}')
    break
print(f'завершена проверка целевой колонки на пустые значения')
# Out:
# Колоноки с пропусками: 4575
# null_cols[1]: ЗаключениеМК
# завершена проверка целевой колонки на пустые значения

# %%
# Отбор данных целевого столбца "ЗаключениеМК"
data[['ЗаключениеМК']]
# Out:
#                 ЗаключениеМК
# 0                      Годен
# 1                      Годен
# 2     ГоденСКоррекциейЗрения
# 3                      Годен
# 4     ГоденСКоррекциейЗрения
# ...                      ...
# 1977                     NaN
# 1978                     NaN
# 1979                     NaN
# 1980                     NaN
# 1981                   Годен
#
# [1982 rows x 1 columns]

# %%
# Для дальнешей работы делаем копию таблицы
data_backup = data.copy()
df = data.copy()

# %%
# проанализируем целевую колонку на уникальные значения
unique_names = df['ЗаключениеМК'].unique().tolist()
print(unique_names)
# Out:
# ['Годен', 'ГоденСКоррекциейЗрения', 'ГоденБезРаботНаВысотах', 'НуждаетсяВДообследованииИЛечении', 'ВременноНегоден', 'ОграниченноГоден', nan, 'машинист бульдозера', 'Газоспасатель', ' Газоспасатель']

# %%
# удаляем строки с очевидными ошибками

# %%
# удаляем nan, 'машинист бульдозера', 'Газоспасатель', ' Газоспасатель'
df = df.drop(df[(df['ЗаключениеМК'].isnull()) | (df['ЗаключениеМК'] == 'машинист бульдозера') | (df['ЗаключениеМК'] == 'Газоспасатель') | (df['ЗаключениеМК'] == ' Газоспасатель') ].index)

# %%
#проверяем список уникальных значений
unique_names2 = df['ЗаключениеМК'].unique().tolist()
print(unique_names2)
# Out:
# ['Годен', 'ГоденСКоррекциейЗрения', 'ГоденБезРаботНаВысотах', 'НуждаетсяВДообследованииИЛечении', 'ВременноНегоден', 'ОграниченноГоден']

# %%
df
# Out:
#              ДокументПрохождениеМедосмотра  \
# 0     7f41ca7e-7dac-11ec-80fc-0cc47aab8067
# 1     2ee1f9ac-83dd-11ec-80fc-0cc47aab8067
# 2     9cbb191e-8e24-11ec-80fe-0cc47aab8067
# 3     b8a33910-8eec-11ec-80fe-0cc47aab8067
# 4     0bb0d181-938c-11ec-80fe-0cc47aab8067
# ...                                    ...
# 1961  fc373292-705b-11ed-8109-0cc47aab8067
# 1962  79a5293f-705c-11ed-8109-0cc47aab8067
# 1972  77b8ed40-7087-11ed-8109-0cc47aab8067
# 1973  46473c2d-7073-11ed-8109-0cc47aab8067
# 1981  a15e278b-71f5-11ed-810a-0cc47aab8067
#
#                                     Клиент КлиентДатаРождения КлиентПол  \
# 0     c91e3407-b81f-11e9-80cf-0cc47aab8067         1976-10-24   Женский
# 1     1a1a5fea-8b7f-11eb-80e8-0cc47aab8067         1987-11-18   Мужской
# 2     7fe324e0-fa51-11eb-80f6-0cc47aab8067         1985-09-08   Мужской
# 3     98f9d761-8d65-11ec-80fe-0cc47aab8067         1988-04-25   Мужской
# 4     009aac7d-7bcf-11eb-80e8-0cc47aab8067         1984-04-17   Мужской
# ...                                    ...                ...       ...
# 1961  d334f0e5-2ff4-11ec-80f9-0cc47aab8067         1993-12-29   Мужской
# 1962  e00ba1a0-2ff4-11ec-80f9-0cc47aab8067         1989-07-10   Мужской
# 1972  90fa4fca-2495-11e9-80ce-0cc47aab8067         1987-02-04   Мужской
# 1973  febbe86c-5f5b-11ea-80dc-0cc47aab8067         1993-02-04   Мужской
# 1981  920293ea-32c2-11eb-80e3-0cc47aab8067         1971-09-14   Мужской
#
#      КлиентПолПредставление ДатаЗавершенияМедосмотра  ТипМедосмотра  \
# 0                   Женский               2022-01-25  Периодический
# 1                   Мужской               2022-02-02  Периодический
# 2                   Мужской               2022-02-15  Периодический
# 3                   Мужской               2022-02-16  Периодический
# 4                   Мужской               2022-02-22  Периодический
# ...                     ...                      ...            ...
# 1961                Мужской               2022-11-30  Периодический
# 1962                Мужской               2022-11-30  Периодический
# 1972                Мужской               2022-11-30  Периодический
# 1973                Мужской               2022-11-30  Периодический
# 1981                Мужской               2022-12-02  Периодический
#
#      ТипМедосмотраПредставление  ПсихОсвидетельствование  \
# 0                 Периодический                    False
# 1                 Периодический                    False
# 2                 Периодический                    False
# 3                 Периодический                    False
# 4                 Периодический                    False
# ...                         ...                      ...
# 1961              Периодический                    False
# 1962              Периодический                    False
# 1972              Периодический                    False
# 1973              Периодический                     True
# 1981              Периодический                    False
#
#                                 Контрагент  ...  \
# 0     23c173a7-30d9-11e7-80d8-708bcd7f83cd  ...
# 1     a6d559b0-7835-11eb-80e8-0cc47aab8067  ...
# 2     a6d559b0-7835-11eb-80e8-0cc47aab8067  ...
# 3     a6d559b0-7835-11eb-80e8-0cc47aab8067  ...
# 4     a6d559b0-7835-11eb-80e8-0cc47aab8067  ...
# ...                                    ...  ...
# 1961  a30f4a53-de4e-11eb-80f6-0cc47aab8067  ...
# 1962  a30f4a53-de4e-11eb-80f6-0cc47aab8067  ...
# 1972  d366a562-5a32-11ea-80db-0cc47aab8067  ...
# 1973  992c8208-4e0d-11ed-8107-0cc47aab8067  ...
# 1981  4826f33a-06b9-11ea-80d3-0cc47aab8067  ...
#
#      Оториноларингология3_Аудиометрия1_Значение  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 1961                                        NaN
# 1962                                        NaN
# 1972                                        NaN
# 1973                                        NaN
# 1981                                        NaN
#
#      Оториноларингология3_Аудиометрия1_ЗначениеПредставление  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1961                                                NaN
# 1962                                                NaN
# 1972                                                NaN
# 1973                                                NaN
# 1981                                                NaN
#
#      Оториноларингология1_ЖалобыДополнение_Значение  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ...                                             ...
# 1961                                            NaN
# 1962                                            NaN
# 1972                                            NaN
# 1973                                            NaN
# 1981                                            NaN
#
#      Оториноларингология1_ЖалобыДополнение_ЗначениеПредставление  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1961                                                NaN
# 1962                                                NaN
# 1972                                                NaN
# 1973                                                NaN
# 1981                                                NaN
#
#      Стоматология2_ВП2_Значение Стоматология2_ВП2_ЗначениеПредставление  \
# 0                           NaN                                     NaN
# 1                           NaN                                     NaN
# 2                           NaN                                     NaN
# 3                           NaN                                     NaN
# 4                           NaN                                     NaN
# ...                         ...                                     ...
# 1961                        NaN                                     NaN
# 1962                        NaN                                     NaN
# 1972                        NaN                                     NaN
# 1973                        NaN                                     NaN
# 1981                        NaN                                     NaN
#
#      Терапия2_ЗаключениеФОГК_Значение  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# ...                               ...
# 1961                              NaN
# 1962                              NaN
# 1972                              NaN
# 1973                              NaN
# 1981                              NaN
#
#      Терапия2_ЗаключениеФОГК_ЗначениеПредставление  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ...                                            ...
# 1961                                           NaN
# 1962                                           NaN
# 1972                                           NaN
# 1973                                           NaN
# 1981                                           NaN
#
#      Офтальмология1_ДвигательныйАппаратГлазДополнение_Значение  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1961                                                NaN
# 1962                                                NaN
# 1972                                                NaN
# 1973                                                NaN
# 1981                                                NaN
#
#      Офтальмология1_ДвигательныйАппаратГлазДополнение_ЗначениеПредставление
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1961                                                NaN
# 1962                                                NaN
# 1972                                                NaN
# 1973                                                NaN
# 1981                                                NaN
#
# [1571 rows x 4587 columns]

# %% [markdown]
# **Количество колонок в датасете уменьшили с 4587 до 419**

# %%
# Удаление столбцов с пропусками, если количество пропусков в признаке больше 50%
null_cols2 = df.columns[df.isna().any()].tolist()
for col2 in null_cols2:
  if df[col2].isna().sum() > 0.5*len(df):
    df = df.drop(col2, axis=1)

print(df.shape)
# Out:
# (1571, 419)

# %% [markdown]
# **Количество колонок в датасете уменьшили с 4587 до 419.**

# %%
# Если пропусков менее 50%, то заменим их на среднее значение в случае численного признака и на наиболее часто встречаемое значение в случае категориального.
# Пройдём циклом по всем колонкам
for i in df.columns:
  # условие, если количество пустых ячеек не 0, но и не более 50%
  if df[i].isna().sum() > 0:
    # Если тип значений столбца 'object' (строковые)
    if df[i].dtype == 'object':
      # То заполняем пустые значения самым частовстречаемым значением этого столбца
      df[i].fillna(df[i].value_counts().index[0], inplace=True)
      # Если тип значений столбца НЕ 'object' (значит численные)
    elif df[i].dtype != 'object':
      # То заполняем пустые значения средним значением
      df[i].fillna(df[i].mean(), inplace=True)

# %%
# Поиск признаков с пропусками
null_cols3 = df.columns[df.isna().any()].tolist()
null_cols_len3 = len(null_cols3)
print(f'Список колонок с пропусками: {null_cols_len3}')
# Out:
# Список колонок с пропусками: 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1571 entries, 0 to 1981
# Columns: 419 entries, ДокументПрохождениеМедосмотра to Терапия1_Диагноз_ЗначениеПредставление
# dtypes: bool(1), datetime64[ns](10), float64(36), object(372)
# memory usage: 5.0+ MB

# %%
df
# Out:
#              ДокументПрохождениеМедосмотра  \
# 0     7f41ca7e-7dac-11ec-80fc-0cc47aab8067
# 1     2ee1f9ac-83dd-11ec-80fc-0cc47aab8067
# 2     9cbb191e-8e24-11ec-80fe-0cc47aab8067
# 3     b8a33910-8eec-11ec-80fe-0cc47aab8067
# 4     0bb0d181-938c-11ec-80fe-0cc47aab8067
# ...                                    ...
# 1961  fc373292-705b-11ed-8109-0cc47aab8067
# 1962  79a5293f-705c-11ed-8109-0cc47aab8067
# 1972  77b8ed40-7087-11ed-8109-0cc47aab8067
# 1973  46473c2d-7073-11ed-8109-0cc47aab8067
# 1981  a15e278b-71f5-11ed-810a-0cc47aab8067
#
#                                     Клиент КлиентДатаРождения КлиентПол  \
# 0     c91e3407-b81f-11e9-80cf-0cc47aab8067         1976-10-24   Женский
# 1     1a1a5fea-8b7f-11eb-80e8-0cc47aab8067         1987-11-18   Мужской
# 2     7fe324e0-fa51-11eb-80f6-0cc47aab8067         1985-09-08   Мужской
# 3     98f9d761-8d65-11ec-80fe-0cc47aab8067         1988-04-25   Мужской
# 4     009aac7d-7bcf-11eb-80e8-0cc47aab8067         1984-04-17   Мужской
# ...                                    ...                ...       ...
# 1961  d334f0e5-2ff4-11ec-80f9-0cc47aab8067         1993-12-29   Мужской
# 1962  e00ba1a0-2ff4-11ec-80f9-0cc47aab8067         1989-07-10   Мужской
# 1972  90fa4fca-2495-11e9-80ce-0cc47aab8067         1987-02-04   Мужской
# 1973  febbe86c-5f5b-11ea-80dc-0cc47aab8067         1993-02-04   Мужской
# 1981  920293ea-32c2-11eb-80e3-0cc47aab8067         1971-09-14   Мужской
#
#      КлиентПолПредставление ДатаЗавершенияМедосмотра  ТипМедосмотра  \
# 0                   Женский               2022-01-25  Периодический
# 1                   Мужской               2022-02-02  Периодический
# 2                   Мужской               2022-02-15  Периодический
# 3                   Мужской               2022-02-16  Периодический
# 4                   Мужской               2022-02-22  Периодический
# ...                     ...                      ...            ...
# 1961                Мужской               2022-11-30  Периодический
# 1962                Мужской               2022-11-30  Периодический
# 1972                Мужской               2022-11-30  Периодический
# 1973                Мужской               2022-11-30  Периодический
# 1981                Мужской               2022-12-02  Периодический
#
#      ТипМедосмотраПредставление  ПсихОсвидетельствование  \
# 0                 Периодический                    False
# 1                 Периодический                    False
# 2                 Периодический                    False
# 3                 Периодический                    False
# 4                 Периодический                    False
# ...                         ...                      ...
# 1961              Периодический                    False
# 1962              Периодический                    False
# 1972              Периодический                    False
# 1973              Периодический                     True
# 1981              Периодический                    False
#
#                                 Контрагент  ...  \
# 0     23c173a7-30d9-11e7-80d8-708bcd7f83cd  ...
# 1     a6d559b0-7835-11eb-80e8-0cc47aab8067  ...
# 2     a6d559b0-7835-11eb-80e8-0cc47aab8067  ...
# 3     a6d559b0-7835-11eb-80e8-0cc47aab8067  ...
# 4     a6d559b0-7835-11eb-80e8-0cc47aab8067  ...
# ...                                    ...  ...
# 1961  a30f4a53-de4e-11eb-80f6-0cc47aab8067  ...
# 1962  a30f4a53-de4e-11eb-80f6-0cc47aab8067  ...
# 1972  d366a562-5a32-11ea-80db-0cc47aab8067  ...
# 1973  992c8208-4e0d-11ed-8107-0cc47aab8067  ...
# 1981  4826f33a-06b9-11ea-80d3-0cc47aab8067  ...
#
#                  Терапия1_Сердце1_Значение  \
# 0     0109dbf8-8e32-11ec-80fe-0cc47aab8067
# 1     0109dbf8-8e32-11ec-80fe-0cc47aab8067
# 2     0109dbf8-8e32-11ec-80fe-0cc47aab8067
# 3     0109dbf8-8e32-11ec-80fe-0cc47aab8067
# 4     0109dbf8-8e32-11ec-80fe-0cc47aab8067
# ...                                    ...
# 1961  0109dbf8-8e32-11ec-80fe-0cc47aab8067
# 1962  0109dbf8-8e32-11ec-80fe-0cc47aab8067
# 1972  0109dbf8-8e32-11ec-80fe-0cc47aab8067
# 1973  0109dbf8-8e32-11ec-80fe-0cc47aab8067
# 1981  0109dbf8-8e32-11ec-80fe-0cc47aab8067
#
#      Терапия1_Сердце1_ЗначениеПредставление Терапия1_ИМТ_Значение  \
# 0                             без патологий                 24.22
# 1                             без патологий                 24.22
# 2                             без патологий                 24.22
# 3                             без патологий                 24.22
# 4                             без патологий                 24.22
# ...                                     ...                   ...
# 1961                          без патологий                 27.76
# 1962                          без патологий                 25.25
# 1972                          без патологий                 26.57
# 1973                          без патологий                 25.26
# 1981                          без патологий                 24.15
#
#      Терапия1_ИМТ_ЗначениеПредставление  \
# 0                             26.170061
# 1                             26.170061
# 2                             26.170061
# 3                             26.170061
# 4                             26.170061
# ...                                 ...
# 1961                          27.760000
# 1962                          25.250000
# 1972                          26.570000
# 1973                          25.260000
# 1981                          24.150000
#
#      Терапия1_АртериальноеДавление21_Значение  \
# 0                                   80.594457
# 1                                   80.594457
# 2                                   80.594457
# 3                                   80.594457
# 4                                   80.594457
# ...                                       ...
# 1961                                70.000000
# 1962                                70.000000
# 1972                                80.000000
# 1973                                71.000000
# 1981                                80.000000
#
#      Терапия1_АртериальноеДавление21_ЗначениеПредставление  \
# 0                                             80.594457
# 1                                             80.594457
# 2                                             80.594457
# 3                                             80.594457
# 4                                             80.594457
# ...                                                 ...
# 1961                                          70.000000
# 1962                                          70.000000
# 1972                                          80.000000
# 1973                                          71.000000
# 1981                                          80.000000
#
#      Терапия1_Курение_Значение Терапия1_Курение_ЗначениеПредставление  \
# 0                     0.036993                                    Нет
# 1                     0.036993                                    Нет
# 2                     0.036993                                    Нет
# 3                     0.036993                                    Нет
# 4                     0.036993                                    Нет
# ...                        ...                                    ...
# 1961                  0.000000                                    Нет
# 1962                  0.000000                                    Нет
# 1972                  1.000000                                     Да
# 1973                  0.000000                                    Нет
# 1981                  1.000000                                     Да
#
#                       Терапия1_Диагноз_Значение  \
# 0     [Z00.0] Общий медицинский осмотр_x000D_\n
# 1     [Z00.0] Общий медицинский осмотр_x000D_\n
# 2     [Z00.0] Общий медицинский осмотр_x000D_\n
# 3     [Z00.0] Общий медицинский осмотр_x000D_\n
# 4     [Z00.0] Общий медицинский осмотр_x000D_\n
# ...                                         ...
# 1961  [Z00.0] Общий медицинский осмотр_x000D_\n
# 1962  [Z00.0] Общий медицинский осмотр_x000D_\n
# 1972  [Z00.0] Общий медицинский осмотр_x000D_\n
# 1973  [Z00.0] Общий медицинский осмотр_x000D_\n
# 1981  [Z00.0] Общий медицинский осмотр_x000D_\n
#
#          Терапия1_Диагноз_ЗначениеПредставление
# 0     [Z00.0] Общий медицинский осмотр_x000D_\n
# 1     [Z00.0] Общий медицинский осмотр_x000D_\n
# 2     [Z00.0] Общий медицинский осмотр_x000D_\n
# 3     [Z00.0] Общий медицинский осмотр_x000D_\n
# 4     [Z00.0] Общий медицинский осмотр_x000D_\n
# ...                                         ...
# 1961  [Z00.0] Общий медицинский осмотр_x000D_\n
# 1962  [Z00.0] Общий медицинский осмотр_x000D_\n
# 1972  [Z00.0] Общий медицинский осмотр_x000D_\n
# 1973  [Z00.0] Общий медицинский осмотр_x000D_\n
# 1981  [Z00.0] Общий медицинский осмотр_x000D_\n
#
# [1571 rows x 419 columns]

# %% [markdown]
# **Датасет заполнен. Пропуски отсутствуют**
